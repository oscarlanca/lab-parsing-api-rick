# %% [markdown]
# # Challenge: Rick and Morty API
#
# ![](http://as01.epimg.net/epik/imagenes/2019/02/12/portada/1549970850_227267_1549973816_noticia_normal.jpg)
#
#
# **In this challenge, you'll develop codes to parse and analyze data returned from the [Rick and Morty API](https://rickandmortyapi.com/).** The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url= 'https://rickandmortyapi.com/api/character/533'

# %%
response = requests.get(url)
results = response.json()
results
# Out:
# {'id': 533,
#  'name': 'Monogatron Queen',
#  'status': 'Alive',
#  'species': 'Alien',
#  'type': 'Monogatron',
#  'gender': 'Female',
#  'origin': {'name': 'unknown', 'url': ''},
#  'location': {'name': 'Monogatron Mothership',
#   'url': 'https://rickandmortyapi.com/api/location/83'},
#  'image': 'https://rickandmortyapi.com/api/character/avatar/533.jpeg',
#  'episode': ['https://rickandmortyapi.com/api/episode/33'],
#  'url': 'https://rickandmortyapi.com/api/character/533',
#  'created': '2020-05-02T13:46:10.906Z'}

# %%
flattened_data = json_normalize(results)
# Out:
# /var/folders/6s/trx_m89s3f32v2bh_vr604r40000gn/T/ipykernel_42146/3247562768.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(results)

# %%
flattened_data
# Out:
#     id              name status species        type  gender  \
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
#
#                                                image  \
# 0  https://rickandmortyapi.com/api/character/avat...
#
#                                         episode  \
# 0  [https://rickandmortyapi.com/api/episode/33]
#
#                                              url                   created  \
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
#
#   origin.name origin.url          location.name  \
# 0     unknown             Monogatron Mothership
#
#                                   location.url
# 0  https://rickandmortyapi.com/api/location/83

# %%
# Out:
# <Response [200]>

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
url_1 = 'https://rickandmortyapi.com/'

# %%
response_1 = requests.get(url_1)
#results_1 = response_1.json()
#results_1
response_1
# Out:
# <Response [200]>

# %%
#results_1 = response_1.json()
df_rick= pd.DataFrame()
for i in range(1,10):
    url_u=f'https://rickandmortyapi.com/api/character?page={i}'
    response_u = requests.get(url_1)
    response_u.raise_for_status()  # raises exception when not a 2xx response
    if response_u.status_code != 204:
        results_u= response.json()
        flattened_data = pd.json_normalize(results_u)
        d = pd.DataFrame(flattened_data)
        df_rick = pd.concat([df_rick,d])
df_rick
# Out:
#     id              name status species        type  gender  \
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
# 0  533  Monogatron Queen  Alive   Alien  Monogatron  Female
#
#                                                image  \
# 0  https://rickandmortyapi.com/api/character/avat...
# 0  https://rickandmortyapi.com/api/character/avat...
# 0  https://rickandmortyapi.com/api/character/avat...
# 0  https://rickandmortyapi.com/api/character/avat...
# 0  https://rickandmortyapi.com/api/character/avat...
# 0  https://rickandmortyapi.com/api/character/avat...
# 0  https://rickandmortyapi.com/api/character/avat...
# 0  https://rickandmortyapi.com/api/character/avat...
# 0  https://rickandmortyapi.com/api/character/avat...
#
#                                         episode  \
# 0  [https://rickandmortyapi.com/api/episode/33]
# 0  [https://rickandmortyapi.com/api/episode/33]
# 0  [https://rickandmortyapi.com/api/episode/33]
# 0  [https://rickandmortyapi.com/api/episode/33]
# 0  [https://rickandmortyapi.com/api/episode/33]
# 0  [https://rickandmortyapi.com/api/episode/33]
# 0  [https://rickandmortyapi.com/api/episode/33]
# 0  [https://rickandmortyapi.com/api/episode/33]
# 0  [https://rickandmortyapi.com/api/episode/33]
#
#                                              url                   created  \
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
# 0  https://rickandmortyapi.com/api/character/533  2020-05-02T13:46:10.906Z
#
#   origin.name origin.url          location.name  \
# 0     unknown             Monogatron Mothership
# 0     unknown             Monogatron Mothership
# 0     unknown             Monogatron Mothership
# 0     unknown             Monogatron Mothership
# 0     unknown             Monogatron Mothership
# 0     unknown             Monogatron Mothership
# 0     unknown             Monogatron Mothership
# 0     unknown             Monogatron Mothership
# 0     unknown             Monogatron Mothership
#
#                                   location.url
# 0  https://rickandmortyapi.com/api/location/83
# 0  https://rickandmortyapi.com/api/location/83
# 0  https://rickandmortyapi.com/api/location/83
# 0  https://rickandmortyapi.com/api/location/83
# 0  https://rickandmortyapi.com/api/location/83
# 0  https://rickandmortyapi.com/api/location/83
# 0  https://rickandmortyapi.com/api/location/83
# 0  https://rickandmortyapi.com/api/location/83
# 0  https://rickandmortyapi.com/api/location/83

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The character who appeared in most episodes (aside from Rick and Morty, of course!).
#
# * The total number of dead characters.
#
# * A list of all character origins (without duplicates).

# %%
# your code here
